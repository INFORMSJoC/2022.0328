# %%
import matplotlib.pyplot as plt

# %%
res1 = [1415.0, 1731.3, 2012.2, 2234.5, 2447.2, 2650.6, 2837.0, 3012.3, 3168.3, 3317.4, 3458.0, 3599.9, 3738.2, 3870.5, 3998.5, 4125.5, 4244.9, 4369.6, 4486.9]

# %%
res2 = [1414.213562373095, 1732.0508075688772, 2000.0, 2236.06797749979, 2449.489742783178, 2645.7513110645905, 2828.42712474619, 3000.0, 3162.2776601683795, 3316.6247903554, 3464.1016151377544, 3605.5512754639894, 3741.657386773941, 3872.983346207417, 4000.0, 4123.105625617661, 4242.640687119285, 4358.898943540674, 4472.13595499958]

# %%
plt.plot(range(10**6, 10**7+1, 5*(10**5)), res2, '-', label = "estimate", color = "red")
plt.plot(range(10**6, 10**7+1, 5*(10**5)), res1, 'o', label = "observed average", color = "blue")
plt.legend()
plt.xlabel("inpt size n")
plt.ylabel("active elements")
resolution_value = 300
plt.savefig("average_active.png", format="png", dpi=resolution_value)
plt.show()

# %%
res1 = [17947.8, 19709.2, 26328.2, 31963.6, 32102.6, 41205.3, 41107.4, 42850.4, 48564.9, 50075.8, 54051.7, 59540.0, 60725.4, 67677.6, 69121.5, 69870.8, 74052.6, 69506.8, 81481.2]
res2 = [16915.381116229833, 22165.41974506151, 26851.493778346252, 31158.398421848742, 35185.410620627335, 38993.64349613307, 42624.0894706644, 46105.9310428577, 49460.87443248698, 52705.6184276906, 55853.35783311689, 58914.74808035105, 61898.550705834576, 64812.08050949355, 67661.52446491933, 70452.17486426665, 73188.60343940558, 75874.79384245924, 78514.24410539685]

# %%
plt.plot(range(10**6, 10**7+1, 5*(10**5)), res2, '-', label = "estimate", color = "red")
plt.plot(range(10**6, 10**7+1, 5*(10**5)), res1, 'o', label = "observed average", color = "blue")
plt.legend()
plt.xlabel("inpt size n")
plt.ylabel("remaining elements")
resolution_value = 300
plt.savefig("filter_result.png", format="png", dpi=resolution_value)
plt.show()

# %%
res1 = [500024.04, 249970.59, 124982.27, 62520.42, 31244.25, 15597.25, 7759.04, 3826.28, 1795.62, 701.12, 155.21, 8.69]
res2 = [500000.0, 250000.0, 125000.0, 62500.0, 31250.0, 15625.0, 7812.5, 3906.25, 1953.125, 976.5625, 488.28125, 244.140625]

# %%
iter_list = [i for i in range(1,13)]

# %%
plt.plot(iter_list, res2, '-', label = "estimate", color = "red")
plt.plot(iter_list, res1, 'o', label = "observed average", color = "blue")
plt.legend()
plt.xticks(iter_list)
plt.xlabel("iterations")
plt.ylabel("remaining elements")
resolution_value = 300
plt.savefig("michelot_loop.png", format="png", dpi=resolution_value)
plt.show()
